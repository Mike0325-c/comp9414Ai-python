# %%
# -*- coding: utf-8 -*-
"""
Created on Sun Jun 11 13:51:04 2023

@author: MaryamHashemi
"""

import numpy as np
import cv2

############################### 3.1 Exercise #####################################

############################ 3.1.1 and 3.1.2 ####################################

#Reading RGB image
img1 = cv2.imread('parrots.jpg')

cv2.imshow('Original image',img1)
print(img1)
print(img1.shape)

img1_red=img1.copy()
img1_red[:,:,2]=255
cv2.imshow('Original image in red',img1_red)


#Reading grey-scale image
img2 = cv2.imread('parrots.jpg',0)
cv2.imshow('Gray-scale image',img2)
print(img2)
print(img2.shape)

cv2.waitKey(0)
cv2.destroyAllWindows()

    

############################ 3.1.3 ####################################

cv2.imwrite('parrots_gray_test.jpg',img2)


############################ 3.1.4 ####################################

#img1 = cv2.imread('parrots.jpg')

height=img1.shape[0]
width=img1.shape[1]
print(height,width)

test=img1.copy()

#Making frame
test[:75,:]=255
test[:,:75]=255
test[height-75:,:]=255
test[:,width-75:]=255
# cv2.rectangle()
cv2.imshow('Frame test',test)
cv2.imwrite('parrots_frame_test.jpg',test)

cv2.waitKey(0)
cv2.destroyAllWindows()


############################ 3.1.5 ####################################

noise=np.random.random((height,width))
noise=noise*50
noise=noise.astype(int)
print(noise)

cv2.imwrite('noise.jpg',noise)
noise=cv2.imread('noise.jpg',0)
cv2.imshow('Noise',noise)

cv2.waitKey(0)
cv2.destroyAllWindows()


############################ 3.1.6 ####################################

noiseimg=noise + img2
result=cv2.imshow('Image noisy',noiseimg)
cv2.imwrite('parrots_noisy_test.jpg', noiseimg)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [1], in <cell line: 18>()
#      11 ############################### 3.1 Exercise #####################################
#      12
#      13 ############################ 3.1.1 and 3.1.2 ####################################
#      14
#      15 #Reading RGB image
#      16 img1 = cv2.imread('parrots.jpg')
# ---> 18 cv2.imshow('Original image',img1)
#      19 print(img1)
#      20 print(img1.shape)
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:973: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
img1 = cv2.imread('COMP9414_Tutorial_7_Solution/parrots.jpg')
# cv2.imshow('Original image',img1)

# print(img1)
print(img1.shape)

# img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)

img1_red=img1.copy()
img1_red[:,:,2]=255

# plt.subplot(1,2,1)
plt.imshow(img1_red)
plt.title('Loaded Image')
plt.axis('off')  # Hide axes

# plt.subplot(1,2,2)
# plt.imshow(img1_red)

# plt.show()


img2 = cv2.imread('COMP9414_Tutorial_7_Solution/parrots.jpg',0)
print(img2.shape)
plt.imshow(img2)

# img2 = cv2.imread('COMP9414_Tutorial_7_Solution/parrots.jpg',0)
# print(img2)
# print(img2.shape)
# img2 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)

# plt.imshow(img2)
# plt.title('it is a img')
# plt.axis('off')  # Hide axes
# plt.show()
# Out:
# (490, 980, 3)
# (490, 980)

# %%
cv2.imwrite('parrots_gray_test.jpg',img2)
# Out:
# True

# %%
height = img1.shape[0]

width = img1.shape[1]
print(height,width)
test = img1.copy()
test[:75,:]=255
test[:,:75]=255
test[height-75:,:]=255
test[:,width-75:]=255
plt.imshow(test)
cv2.imwrite('parrots_frame_test.jpg',test)
# Out:
# 490 980
# True

# %%
noise=np.random.random((height,width))
noise=noise*50
noise=noise.astype(int)
print(noise)
print(noise.shape)
cv2.imwrite('noise.jpg',noise)
noise=cv2.imread('noise.jpg',0)
plt.imshow(noise)



noiseimg=noise + img2
plt.imshow(noiseimg)
plt.title("jjy")
plt.xlabel('3')
cv2.imwrite('parrots_noisy_test.jpg', noiseimg)
# Out:
# [[40  2 10 ... 47  2 40]
#  [12 11 30 ... 25 23 46]
#  [45 40 21 ... 44 43 31]
#  ...
#  [40 38 46 ... 31 40  1]
#  [16 12 10 ... 33 17 49]
#  [32 20 31 ... 17 41 40]]
# (490, 980)
# True

# %%
print(np.random.randint(22, size=(10,2)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 print(np.random.randint(22, size=(10,2)))
#
# NameError: name 'np' is not defined

# %%
np.random.rand(2,3)
# np.random.random(3,2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 2>()
#       1 np.random.rand(2,3)
# ----> 2 np.random.random(3,2)
#
# File numpy\\random\\mtrand.pyx:439, in numpy.random.mtrand.RandomState.random()
#
# TypeError: random() takes at most 1 positional argument (2 given)

# %%
val = 3
nums = [3,2,2,3]
number = 0
for i in nums:
    if i == val:
        nums.remove(i)
        number+=1

k = len(nums)-number
print(nums)
# Out:
# [2, 2]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
