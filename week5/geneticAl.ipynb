# %%
# Python3 program to create target string, starting from 
# random string using Genetic Algorithm 
  
import random 
  
# Number of individuals in each generation 
POPULATION_SIZE = 100
  
# Valid genes 
GENES = '''abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOP 
QRSTUVWXYZ 1234567890, .-;:_!"#%&/()=?@${[]}'''
  
# Target string to be generated 
TARGET = "I love GeeksforGeeks"
  
class Individual(object): 
    ''' 
    Class representing individual in population 
    '''
    def __init__(self, chromosome): 
        self.chromosome = chromosome  
        self.fitness = self.cal_fitness() 
  
    @classmethod
    def mutated_genes(self): 
        ''' 
        create random genes for mutation 
        '''
        global GENES 
        gene = random.choice(GENES) 
        return gene 
  
    @classmethod
    def create_gnome(self): 
        ''' 
        create chromosome or string of genes 
        '''
        global TARGET 
        gnome_len = len(TARGET) 
        return [self.mutated_genes() for _ in range(gnome_len)] 
  
    def mate(self, par2): 
        ''' 
        Perform mating and produce new offspring 
        '''
  
        # chromosome for offspring 
        child_chromosome = [] 
        for gp1, gp2 in zip(self.chromosome, par2.chromosome):     
  
            # random probability   
            prob = random.random() 
  
            # if prob is less than 0.45, insert gene 
            # from parent 1  
            if prob < 0.45: 
                child_chromosome.append(gp1) 
  
            # if prob is between 0.45 and 0.90, insert 
            # gene from parent 2 
            elif prob < 0.90: 
                child_chromosome.append(gp2) 
  
            # otherwise insert random gene(mutate),  
            # for maintaining diversity 
            else: 
                child_chromosome.append(self.mutated_genes()) 
  
        # create new Individual(offspring) using  
        # generated chromosome for offspring 
        return Individual(child_chromosome) 
  
    def cal_fitness(self): 
        ''' 
        Calculate fitness score, it is the number of 
        characters in string which differ from target 
        string. 
        '''
        global TARGET 
        fitness = 0
        for gs, gt in zip(self.chromosome, TARGET): 
            if gs != gt: fitness+= 1
        return fitness 
  
# Driver code 
def main(): 
    global POPULATION_SIZE 
  
    #current generation 
    generation = 1
  
    found = False
    population = [] 
  
    # create initial population 
    for _ in range(POPULATION_SIZE): 
                gnome = Individual.create_gnome() 
                population.append(Individual(gnome)) 
  
    while not found: 
  
        # sort the population in increasing order of fitness score 
        population = sorted(population, key = lambda x:x.fitness) 
  
        # if the individual having lowest fitness score ie.  
        # 0 then we know that we have reached to the target 
        # and break the loop 
        if population[0].fitness <= 0: 
            found = True
            break
  
        # Otherwise generate new offsprings for new generation 
        new_generation = [] 
  
        # Perform Elitism, that mean 10% of fittest population 
        # goes to the next generation 
        s = int((10*POPULATION_SIZE)/100) 
        new_generation.extend(population[:s]) 
  
        # From 50% of fittest population, Individuals  
        # will mate to produce offspring 
        s = int((90*POPULATION_SIZE)/100) 
        for _ in range(s): 
            parent1 = random.choice(population[:50]) 
            parent2 = random.choice(population[:50]) 
            child = parent1.mate(parent2) 
            new_generation.append(child) 
  
        population = new_generation 
  
        print("Generation: {}\tString: {}\tFitness: {}".
    format(generation, 
              "".join(population[0].chromosome), 
              population[0].fitness)) 
  
        generation += 1
  
      
    print("Generation: {}\tString: {}\tFitness: {}". 
          format(generation, 
          "".join(population[0].chromosome), 
          population[0].fitness)) 
  
if __name__ == '__main__': 
    main()
# Out:
# Generation: 1	String:
#  I4v:Ba@" sjmWVX0,}	Fitness: 17
# Generation: 2	String:
#  I4v:Ba@" sjmWVX0,}	Fitness: 17
# Generation: 3	String:
#  I4v:Ba@" sjmWVX0,}	Fitness: 17
# Generation: 4	String: j_k%v-=]Z2kJ(o3(wD&s	Fitness: 16
# Generation: 5	String: j_k%v-=]Z2kJ(o3(wD&s	Fitness: 16
# Generation: 6	String: j_k%v-=]Z2kJ(o3(wD&s	Fitness: 16
# Generation: 7	String: d R%v;;n,ek6(wn, Oqs	Fitness: 15
# Generation: 8	String: I R,v ]CGeQ!fjr,%D
# s	Fitness: 13
# Generation: 9	String: I R,v ]CGeQ!fjr,%D
# s	Fitness: 13
# Generation: 10	String: I I3vT aGXksfodVkF n	Fitness: 12
# Generation: 11	String: I I3vT aGXksfodVkF n	Fitness: 12
# Generation: 12	String: I %{vT ,QeksfmdVkA-s	Fitness: 11
# Generation: 13	String: I R{v; CZeksfo=35hds	Fitness: 10
# Generation: 14	String: I R{v; CZeksfo=35hds	Fitness: 10
# Generation: 15	String: I R{v; CZeksfo=35hds	Fitness: 10
# Generation: 16	String: I R{v; CZeksfo=35hds	Fitness: 10
# Generation: 17	String: I KTvT aFeksfor5M7Fs	Fitness: 9
# Generation: 18	String: I KTvT aFeksfor5M7Fs	Fitness: 9
# Generation: 19	String: I KTvT aFeksfor5M7Fs	Fitness: 9
# Generation: 20	String: I lTvO C@eksfor5M7 s	Fitness: 8
# Generation: 21	String: I lTvO C@eksfor5M7 s	Fitness: 8
# Generation: 22	String: I lTvO C@eksfor5M7 s	Fitness: 8
# Generation: 23	String: I lov= a@eksfor5-F/s	Fitness: 7
# Generation: 24	String: I lov= a@eksfor5-F/s	Fitness: 7
# Generation: 25	String: I lov= a@eksfor5-F/s	Fitness: 7
# Generation: 26	String: I lovN afeksfor55Fks	Fitness: 6
# Generation: 27	String: I lovN afeksfor55Fks	Fitness: 6
# Generation: 28	String: I lovC a2eksforTeFks	Fitness: 5
# Generation: 29	String: I lovC a2eksforTeFks	Fitness: 5
# Generation: 30	String: I lovC a2eksforTeFks	Fitness: 5
# Generation: 31	String: I lovC a2eksforTeFks	Fitness: 5
# Generation: 32	String: I lovC a2eksforTeFks	Fitness: 5
# Generation: 33	String: I lovC a2eksforTeFks	Fitness: 5
# Generation: 34	String: I lovC a2eksforTeFks	Fitness: 5
# Generation: 35	String: I lov= a2eksforMeeks	Fitness: 4
# Generation: 36	String: I lov= a2eksforMeeks	Fitness: 4
# Generation: 37	String: I lov= a2eksforMeeks	Fitness: 4
# Generation: 38	String: I lov= a2eksforMeeks	Fitness: 4
# Generation: 39	String: I lov= a2eksforMeeks	Fitness: 4
# Generation: 40	String: I lov= a2eksforMeeks	Fitness: 4
# Generation: 41	String: I lov= a2eksforMeeks	Fitness: 4
# Generation: 42	String: I lov= a2eksforMeeks	Fitness: 4
# Generation: 43	String: I lov= a2eksforMeeks	Fitness: 4
# Generation: 44	String: I lov= a2eksforMeeks	Fitness: 4
# Generation: 45	String: I lov= a2eksforMeeks	Fitness: 4
# Generation: 46	String: I lov= a2eksforMeeks	Fitness: 4
# Generation: 47	String: I lov= a2eksforMeeks	Fitness: 4
# Generation: 48	String: I lov= a2eksforMeeks	Fitness: 4
# Generation: 49	String: I lov= a2eksforMeeks	Fitness: 4
# Generation: 50	String: I lov= a2eksforMeeks	Fitness: 4
# Generation: 51	String: I lov= a2eksforMeeks	Fitness: 4
# Generation: 52	String: I lov= a2eksforMeeks	Fitness: 4
# Generation: 53	String: I lov= a2eksforMeeks	Fitness: 4
# Generation: 54	String: I lov= a2eksforMeeks	Fitness: 4
# Generation: 55	String: I lovO k6eksforGeeks	Fitness: 3
# Generation: 56	String: I lovP xeeksforGeeks	Fitness: 2
# Generation: 57	String: I lovP xeeksforGeeks	Fitness: 2
# Generation: 58	String: I lovP xeeksforGeeks	Fitness: 2
# Generation: 59	String: I lovP xeeksforGeeks	Fitness: 2
# Generation: 60	String: I lovP xeeksforGeeks	Fitness: 2
# Generation: 61	String: I lovP xeeksforGeeks	Fitness: 2
# Generation: 62	String: I lovP xeeksforGeeks	Fitness: 2
# Generation: 63	String: I lovP xeeksforGeeks	Fitness: 2
# Generation: 64	String: I lovP xeeksforGeeks	Fitness: 2
# Generation: 65	String: I lovP xeeksforGeeks	Fitness: 2
# Generation: 66	String: I lovP xeeksforGeeks	Fitness: 2
# Generation: 67	String: I lovP xeeksforGeeks	Fitness: 2
# Generation: 68	String: I lovP xeeksforGeeks	Fitness: 2
# Generation: 69	String: I lovP xeeksforGeeks	Fitness: 2
# Generation: 70	String: I lovP xeeksforGeeks	Fitness: 2
# Generation: 71	String: I lovP xeeksforGeeks	Fitness: 2
# Generation: 72	String: I lovP xeeksforGeeks	Fitness: 2
# Generation: 73	String: I lovP xeeksforGeeks	Fitness: 2
# Generation: 74	String: I lovP xeeksforGeeks	Fitness: 2
# Generation: 75	String: I lovP xeeksforGeeks	Fitness: 2
# Generation: 76	String: I lovP xeeksforGeeks	Fitness: 2
# Generation: 77	String: I lovP xeeksforGeeks	Fitness: 2
# Generation: 78	String: I lovP xeeksforGeeks	Fitness: 2
# Generation: 79	String: I lovP xeeksforGeeks	Fitness: 2
# Generation: 80	String: I lovP xeeksforGeeks	Fitness: 2
# Generation: 81	String: I lovP xeeksforGeeks	Fitness: 2
# Generation: 82	String: I lovP xeeksforGeeks	Fitness: 2
# Generation: 83	String: I lovP xeeksforGeeks	Fitness: 2
# Generation: 84	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 85	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 86	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 87	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 88	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 89	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 90	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 91	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 92	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 93	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 94	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 95	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 96	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 97	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 98	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 99	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 100	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 101	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 102	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 103	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 104	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 105	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 106	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 107	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 108	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 109	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 110	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 111	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 112	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 113	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 114	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 115	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 116	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 117	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 118	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 119	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 120	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 121	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 122	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 123	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 124	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 125	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 126	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 127	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 128	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 129	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 130	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 131	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 132	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 133	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 134	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 135	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 136	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 137	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 138	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 139	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 140	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 141	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 142	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 143	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 144	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 145	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 146	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 147	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 148	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 149	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 150	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 151	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 152	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 153	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 154	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 155	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 156	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 157	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 158	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 159	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 160	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 161	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 162	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 163	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 164	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 165	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 166	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 167	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 168	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 169	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 170	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 171	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 172	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 173	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 174	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 175	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 176	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 177	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 178	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 179	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 180	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 181	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 182	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 183	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 184	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 185	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 186	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 187	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 188	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 189	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 190	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 191	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 192	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 193	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 194	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 195	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 196	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 197	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 198	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 199	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 200	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 201	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 202	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 203	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 204	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 205	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 206	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 207	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 208	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 209	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 210	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 211	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 212	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 213	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 214	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 215	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 216	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 217	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 218	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 219	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 220	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 221	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 222	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 223	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 224	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 225	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 226	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 227	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 228	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 229	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 230	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 231	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 232	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 233	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 234	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 235	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 236	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 237	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 238	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 239	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 240	String: I lovm GeeksforGeeks	Fitness: 1
# Generation: 241	String: I love GeeksforGeeks	Fitness: 0
