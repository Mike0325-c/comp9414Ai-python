# %%
import pandas as pd
import numpy as np
# Set the number of models and metrics
num_models = 10
num_metrics = 3

# Generate random performance metrics for each model
performance_metrics = np.random.rand(num_models, num_metrics)
print(performance_metrics.shape)
print(performance_metrics)

# Create a DataFrame from the performance metrics

dataset = pd.DataFrame(performance_metrics, columns=['Accuracy', 'Precision', 'Recall'])
print(dataset, type(dataset))

# Save the DataFrame to a CSV file
dataset.to_csv('performance_metrics.csv', index=False)
# Out:
# (10, 3)
# [[0.03233228 0.91993549 0.19525647]
#  [0.13665477 0.22356307 0.38163018]
#  [0.90990883 0.38636301 0.95835275]
#  [0.90393719 0.90354562 0.93870045]
#  [0.68970554 0.98462787 0.92925867]
#  [0.26251071 0.8148591  0.87603196]
#  [0.84140575 0.38140379 0.23959827]
#  [0.49888366 0.07070869 0.21718958]
#  [0.12605139 0.96290871 0.26696665]
#  [0.45654249 0.38067976 0.00994737]]
#    Accuracy  Precision    Recall
# 0  0.032332   0.919935  0.195256
# 1  0.136655   0.223563  0.381630
# 2  0.909909   0.386363  0.958353
# 3  0.903937   0.903546  0.938700
# 4  0.689706   0.984628  0.929259
# 5  0.262511   0.814859  0.876032
# 6  0.841406   0.381404  0.239598
# 7  0.498884   0.070709  0.217190
# 8  0.126051   0.962909  0.266967
# 9  0.456542   0.380680  0.009947 <class 'pandas.core.frame.DataFrame'>

# %%
import matplotlib.pyplot as plt
# Calculate the mean and standard deviation of each metric across all models
mean_metrics = dataset.mean()
std_metrics = dataset.std()


# Visualize the mean performance of each metric using a bar chart with error bars
metrics = ['Accuracy', 'Precision', 'Recall']
plt.bar(metrics, mean_metrics, yerr=std_metrics, capsize=5)
plt.xlabel('Metrics')
plt.ylabel('Mean Value')
plt.title('Mean Performance of Metrics')

# Add labels to the error bars
for i, metric in enumerate(metrics):
    plt.text(i, mean_metrics[i] + std_metrics[i] + 0.01, f"std: {std_metrics[i]:.2f}", ha='center')

plt.show()

# Create subplots for each metric
fig, axes = plt.subplots(num_metrics, 1, figsize=(8, 6))
# Iterate over metrics and plot performance for each model
metrics = ['Accuracy', 'Precision', 'Recall']
for i, metric in enumerate(metrics):
    ax = axes[i]
    ax.plot(dataset.index, dataset[metric])
    ax.set_xlabel('Models')
    ax.set_ylabel(metric)
    ax.set_title(f'Performance of Models on {metric}')

# Adjust spacing between subplots
plt.tight_layout()

# Display the subplots
plt.show()

df = pd.read_csv('performance_metrics.csv')
print(df)
print(df.loc[0])
print(df.loc[[0,1]])
print("head")
print(df.head(10))

print(mean_metrics[1],'mean')
# Out:
#    Accuracy  Precision    Recall
# 0  0.032332   0.919935  0.195256
# 1  0.136655   0.223563  0.381630
# 2  0.909909   0.386363  0.958353
# 3  0.903937   0.903546  0.938700
# 4  0.689706   0.984628  0.929259
# 5  0.262511   0.814859  0.876032
# 6  0.841406   0.381404  0.239598
# 7  0.498884   0.070709  0.217190
# 8  0.126051   0.962909  0.266967
# 9  0.456542   0.380680  0.009947
# Accuracy     0.032332
# Precision    0.919935
# Recall       0.195256
# Name: 0, dtype: float64
#    Accuracy  Precision    Recall
# 0  0.032332   0.919935  0.195256
# 1  0.136655   0.223563  0.381630
# head
#    Accuracy  Precision    Recall
# 0  0.032332   0.919935  0.195256
# 1  0.136655   0.223563  0.381630
# 2  0.909909   0.386363  0.958353
# 3  0.903937   0.903546  0.938700
# 4  0.689706   0.984628  0.929259
# 5  0.262511   0.814859  0.876032
# 6  0.841406   0.381404  0.239598
# 7  0.498884   0.070709  0.217190
# 8  0.126051   0.962909  0.266967
# 9  0.456542   0.380680  0.009947
# 0.6028595105582928 mean
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import pandas

mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

myvar = pandas.DataFrame(mydataset)

print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
import pandas as pd

a = [1, 7, 2]

myvar = pd.Series(a, index = ["x", "y", "z"])

print(myvar)
print(myvar["x"])


data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

myvar = pd.DataFrame(data)

print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64
# 1
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45
