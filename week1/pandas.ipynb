# %%
import pandas as pd
import numpy as np
# Set the number of models and metrics
num_models = 10
num_metrics = 3

# Generate random performance metrics for each model
performance_metrics = np.random.rand(num_models, num_metrics)
# print(performance_metrics.shape)
# print(performance_metrics)

# Create a DataFrame from the performance metrics

dataset = pd.DataFrame(performance_metrics, columns=['Accuracy', 'Precision', 'Recall'])
print(dataset)
# dataset.to_csc
# Save the DataFrame to a CSV file
dataset.to_csv('performance_metrics.csv', index=False)
print(dataset.index)
# Out:
#    Accuracy  Precision    Recall
# 0  0.693261   0.197678  0.933145
# 1  0.892038   0.699495  0.985606
# 2  0.145006   0.773735  0.918572
# 3  0.554667   0.226680  0.688431
# 4  0.386134   0.438503  0.817027
# 5  0.960834   0.133647  0.541442
# 6  0.241338   0.760198  0.749774
# 7  0.412395   0.390165  0.027496
# 8  0.452257   0.269899  0.867271
# 9  0.328298   0.208342  0.543271
# RangeIndex(start=0, stop=10, step=1)
# 0    0.693261
# 1    0.892038
# 2    0.145006
# 3    0.554667
# 4    0.386134
# 5    0.960834
# 6    0.241338
# 7    0.412395
# 8    0.452257
# 9    0.328298
# Name: Accuracy, dtype: float64

# %%
import matplotlib.pyplot as plt
# Calculate the mean and standard deviation of each metric across all models
mean_metrics = dataset.mean()
std_metrics = dataset.std()
print(mean_metrics)

# Visualize the mean performance of each metric using a bar chart with error bars
metrics = ['Accuracy', 'Precision', 'Recall']
plt.bar(metrics, mean_metrics, yerr=std_metrics, capsize=5)
plt.xlabel('Metrics')
plt.ylabel('Mean Value')
plt.title('Mean Performance of Metrics')

# Add labels to the error bars
for i, metric in enumerate(metrics):
    plt.text(i, mean_metrics[i] + std_metrics[i] + 0.01, f"std:ww {std_metrics[i]:.2f}", ha='center')
# plt.text('323')
plt.show()

# Create subplots for each metric
fig, axes = plt.subplots(num_metrics, 1, figsize=(8, 6))
print(axes[0])
# Iterate over metrics and plot performance for each model
metrics = ['Accuracy', 'Precision', 'Recall']
for i, metric in enumerate(metrics):
    ax = axes[i]
    ax.plot(dataset.index, dataset[metric])
    ax.set_xlabel('Models')
    ax.set_ylabel(metric)
    ax.set_title(f'Performance of Models on {metric}')
    

    
# Adjust spacing between subplots
plt.tight_layout()

# Display the subplots
plt.show()


df = pd.read_csv('performance_metrics.csv')
print(df)
print(df.loc[0])
print(df.loc[[0,1]])
print("head")
print(df.head(10))

print(mean_metrics[1],'mean')
# Out:
# Accuracy     0.525870
# Precision    0.364287
# Recall       0.516172
# dtype: float64
# AxesSubplot(0.125,0.657941;0.775x0.222059)
#    Accuracy  Precision    Recall
# 0  0.978228   0.286878  0.130810
# 1  0.129385   0.332968  0.632648
# 2  0.905380   0.047961  0.737737
# 3  0.127112   0.602965  0.579326
# 4  0.670724   0.418708  0.258778
# 5  0.159730   0.117111  0.548317
# 6  0.316974   0.505336  0.302408
# 7  0.817192   0.238294  0.508189
# 8  0.621957   0.699388  0.630055
# 9  0.532017   0.393256  0.833456
# Accuracy     0.978228
# Precision    0.286878
# Recall       0.130810
# Name: 0, dtype: float64
#    Accuracy  Precision    Recall
# 0  0.978228   0.286878  0.130810
# 1  0.129385   0.332968  0.632648
# head
#    Accuracy  Precision    Recall
# 0  0.978228   0.286878  0.130810
# 1  0.129385   0.332968  0.632648
# 2  0.905380   0.047961  0.737737
# 3  0.127112   0.602965  0.579326
# 4  0.670724   0.418708  0.258778
# 5  0.159730   0.117111  0.548317
# 6  0.316974   0.505336  0.302408
# 7  0.817192   0.238294  0.508189
# 8  0.621957   0.699388  0.630055
# 9  0.532017   0.393256  0.833456
# 0.3642865650174272 mean

# %%
import pandas

mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}


myvar = pandas.DataFrame(mydataset)

print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
import pandas as pd

a = [1, 7, 2]

myvar = pd.Series(a, index = ["x", "y", "z"])

print(myvar)
print(myvar["x"])


data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

myvar = pd.DataFrame(data)

print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64
# 1
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45
