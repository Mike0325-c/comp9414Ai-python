# %%
import pandas as pd
import numpy as np
# Set the number of models and metrics
num_models = 10
num_metrics = 3

# Generate random performance metrics for each model
performance_metrics = np.random.rand(num_models, num_metrics)
print(performance_metrics.shape)
print(performance_metrics)

# Create a DataFrame from the performance metrics

dataset = pd.DataFrame(performance_metrics, columns=['Accuracy', 'Precision', 'Recall'])
print(dataset, type(dataset))

# Save the DataFrame to a CSV file
dataset.to_csv('performance_metrics.csv', index=False)
# Out:
# (10, 3)
# [[0.31814505 0.91099025 0.44152708]
#  [0.12904397 0.01478985 0.52925329]
#  [0.76167674 0.69872786 0.56910104]
#  [0.41069037 0.08563527 0.03806247]
#  [0.51215351 0.70005785 0.5237827 ]
#  [0.34396237 0.36097007 0.55985815]
#  [0.18759301 0.29606276 0.39408863]
#  [0.36309852 0.08532369 0.65956679]
#  [0.36700302 0.24339725 0.84006762]
#  [0.36317099 0.00361382 0.5358936 ]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [17], in <cell line: 14>()
#      10 print(performance_metrics)
#      12 # Create a DataFrame from the performance metrics
# ---> 14 dataset = pd.DataFrame(performance_metrics, columns=['Accuracy', 'Precision', 'Recall'],index = ["day1", "day2", "day3"])
#      15 print(dataset, type(dataset))
#      17 # Save the DataFrame to a CSV file
#
# File e:\python3.10\lib\site-packages\pandas\core\frame.py:758, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     747         mgr = dict_to_mgr(
#     748             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     749             # attribute "name"
#    (...)
#     755             copy=_copy,
#     756         )
#     757     else:
# --> 758         mgr = ndarray_to_mgr(
#     759             data,
#     760             index,
#     761             columns,
#     762             dtype=dtype,
#     763             copy=copy,
#     764             typ=manager,
#     765         )
#     767 # For data is list-like, or Iterable (will consume into list)
#     768 elif is_list_like(data):
#
# File e:\python3.10\lib\site-packages\pandas\core\internals\construction.py:337, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     332 # _prep_ndarraylike ensures that values.ndim == 2 at this point
#     333 index, columns = _get_axes(
#     334     values.shape[0], values.shape[1], index=index, columns=columns
#     335 )
# --> 337 _check_values_indices_shape_match(values, index, columns)
#     339 if typ == "array":
#     340     if issubclass(values.dtype.type, str):
#
# File e:\python3.10\lib\site-packages\pandas\core\internals\construction.py:408, in _check_values_indices_shape_match(values, index, columns)
#     406 passed = values.shape
#     407 implied = (len(index), len(columns))
# --> 408 raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#
# ValueError: Shape of passed values is (10, 3), indices imply (3, 3)

# %%
import matplotlib.pyplot as plt
# Calculate the mean and standard deviation of each metric across all models
mean_metrics = dataset.mean()
std_metrics = dataset.std()

# Visualize the mean performance of each metric using a bar chart with error bars
metrics = ['Accuracy', 'Precision', 'Recall']
plt.bar(metrics, mean_metrics, yerr=std_metrics, capsize=5)
plt.xlabel('Metrics')
plt.ylabel('Mean Value')
plt.title('Mean Performance of Metrics')

# Add labels to the error bars
for i, metric in enumerate(metrics):
    plt.text(i, mean_metrics[i] + std_metrics[i] + 0.01, f"std: {std_metrics[i]:.2f}", ha='center')

plt.show()

# Create subplots for each metric
fig, axes = plt.subplots(num_metrics, 1, figsize=(8, 6))
# Iterate over metrics and plot performance for each model
metrics = ['Accuracy', 'Precision', 'Recall']
for i, metric in enumerate(metrics):
    ax = axes[i]
    ax.plot(dataset.index, dataset[metric])
    ax.set_xlabel('Models')
    ax.set_ylabel(metric)
    ax.set_title(f'Performance of Models on {metric}')

# Adjust spacing between subplots
plt.tight_layout()

# Display the subplots
plt.show()

df = pd.read_csv('performance_metrics.csv')
print(df)
print(df.loc[0])
print(df.loc[[0,1]])
print("head")
print(df.head(10))
# Out:
#    Accuracy  Precision    Recall
# 0  0.845275   0.143402  0.863546
# 1  0.497149   0.993084  0.660548
# 2  0.855356   0.679064  0.279697
# 3  0.448631   0.187146  0.807329
# 4  0.263369   0.316715  0.992259
# 5  0.892182   0.178659  0.754404
# 6  0.294374   0.520822  0.057461
# 7  0.362236   0.612709  0.322271
# 8  0.157139   0.801183  0.418819
# 9  0.207817   0.712832  0.045736
# Accuracy     0.845275
# Precision    0.143402
# Recall       0.863546
# Name: 0, dtype: float64
#    Accuracy  Precision    Recall
# 0  0.845275   0.143402  0.863546
# 1  0.497149   0.993084  0.660548

# %%
import pandas

mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

myvar = pandas.DataFrame(mydataset)

print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
import pandas as pd

a = [1, 7, 2]

myvar = pd.Series(a, index = ["x", "y", "z"])

print(myvar)
print(myvar["x"])


data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

myvar = pd.DataFrame(data)

print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64
# 1
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45
